# %%
#! pip install pymysql
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 560.5 kB/s eta 0:00:00 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
#! pip install mysql_connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 4.2 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql_connector: filename=mysql_connector-2.2.9-cp39-cp39-macosx_10_9_x86_64.whl size=247956 sha256=68e15cdac2ba38d80dbb2c30cd3b2884a65cd89aa81b8ec85a4279a617e1959b
#   Stored in directory: /Users/sandhyaanu/Library/Caches/pip/wheels/7b/14/39/5aad423666e827dfe9a1fbcd111ac17171e7c9865d570780ce
# Successfully built mysql_connector
# ...
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import  mysql.connector
import pandas as pd
import numpy as np

# %%
# 127.0.0.1 local host

# %%
db = mysql.connector.connect(host="18.136.157.135",
                             user="dm_user_sql",password="37z49REb$nK@nlpV!vJ")

# %%
# cursor

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
cursor= db.cursor()

# %%
cursor.execute("show databases")  #query

# %%
for i in cursor:
    print(i)
# Out:
# ('information_schema',)
# ('datamites_sql',)

# %%
sqldb = mysql.connector.connect(host="18.136.157.135",
                             user="dm_user_sql",password="37z49REb$nK@nlpV!vJ",database="datamites_sql")

# %%
tables=pd.read_sql_query("show tables",sqldb)

# %%
tables
# Out:
#   Tables_in_datamites_sql
# 0                 Country
# 1               customers
# 2                    dept
# 3                     emp
# 4                  orders
# 5                products
# 6                salgrade

# %%
query1="select * from Country"

# %%
op=pd.read_sql_query(query1,sqldb)
op
# Out:
#   Country_name country_name_eng country_code
# 0  Deutschland          Germany          DEU
# 1       Srbija           Serbia          SRB
# 2     Hrvatska          Croatia          HRV
# 3       Polska           Poland          POL
# 4          USA              USA          USA

# %%
query1="select * from emp"

# %%
op=pd.read_sql_query(query1,sqldb)
op
# Out:
#     empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0    7369   SMITH      CLERK  7902.0  1993-06-13   800.0     0.0      20
# 1    7499   ALLEN   SALESMAN  7698.0  1998-08-15  1600.0   300.0      30
# 2    7521    WARD   SALESMAN  7698.0  1996-03-26  1250.0   500.0      30
# 3    7566   JONES    MANAGER  7839.0  1995-10-31  2975.0     NaN      20
# 4    7654  MARTIN   SALESMAN  7698.0  1998-12-05  1250.0  1400.0      30
# 5    7698   BLAKE    MANAGER  7839.0  1992-06-11  2850.0     NaN      30
# 6    7782   CLARK    MANAGER  7839.0  1993-05-14  2450.0     NaN      10
# 7    7788   SCOTT    ANALYST  7566.0  1996-03-05  3000.0     NaN      20
# 8    7839    KING  PRESIDENT     NaN  1990-06-09  5000.0     0.0      10
# 9    7844  TURNER   SALESMAN  7698.0  1995-06-04  1500.0     0.0      30
# 10   7876   ADAMS      CLERK  7788.0  1999-06-04  1100.0     NaN      20
# 11   7900   JAMES      CLERK  7698.0  2000-06-23   950.0     NaN      30
# ...

# %%
query2="select * from emp where sal>2000"
op= pd.read_sql_query(query2,sqldb)
op
# Out:
#    empno  ename        job     mgr    hiredate     sal  comm  deptno
# 0   7566  JONES    MANAGER  7839.0  1995-10-31  2975.0   NaN      20
# 1   7698  BLAKE    MANAGER  7839.0  1992-06-11  2850.0   NaN      30
# 2   7782  CLARK    MANAGER  7839.0  1993-05-14  2450.0   NaN      10
# 3   7788  SCOTT    ANALYST  7566.0  1996-03-05  3000.0   NaN      20
# 4   7839   KING  PRESIDENT     NaN  1990-06-09  5000.0   0.0      10
# 5   7902   FORD    ANALYST  7566.0  1997-12-05  3000.0   NaN      20

# %%
query3="select * from emp where job= 'MANAGER'"

# %%
op= pd.read_sql_query(query3,sqldb)
op
# Out:
#    empno  ename      job   mgr    hiredate     sal  comm  deptno
# 0   7566  JONES  MANAGER  7839  1995-10-31  2975.0  None      20
# 1   7698  BLAKE  MANAGER  7839  1992-06-11  2850.0  None      30
# 2   7782  CLARK  MANAGER  7839  1993-05-14  2450.0  None      10

# %%
query4="select * from products"

# %%
op=pd.read_sql_query(query4,sqldb)
op
# Out:
#          product_id         category sub_category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-CH-10000454        Furniture       Chairs
# 2   FUR-FU-10001487        Furniture  Furnishings
# 3   FUR-TA-10000577        Furniture       Tables
# 4   FUR-TA-10001539        Furniture       Tables
# 5   OFF-AP-10002892  Office Supplies   Appliances
# 6   OFF-AR-10002833  Office Supplies          Art
# 7   OFF-BI-10003656  Office Supplies      Binders
# 8   OFF-BI-10003910  Office Supplies      Binders
# 9   OFF-LA-10000240  Office Supplies       Labels
# 10  OFF-PA-10002365  Office Supplies        Paper
# 11  OFF-ST-10000760  Office Supplies      Storage
# 12  TEC-PH-10002033       Technology       Phones
# 13  TEC-PH-10002275       Technology       Phones
#
#                                          product_name
# 0                   Bush Somerset Collection Bookcase
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...
# ...

# %%
query5="select * from products where category= 'Furniture'" # * is select all

# %%
op= pd.read_sql_query(query5,sqldb)
op
# Out:
#         product_id   category sub_category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
# 2  FUR-FU-10001487  Furniture  Furnishings
# 3  FUR-TA-10000577  Furniture       Tables
# 4  FUR-TA-10001539  Furniture       Tables
#
#                                         product_name
# 0                  Bush Somerset Collection Bookcase
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  Eldon Expressions Wood and Plastic Desk Access...
# 3      Bretford CR4500 Series Slim Rectangular Table
# 4           Chromcraft Rectangular Conference Tables

# %%
query6="select product_id from products where category= 'Furniture'"

# %%
op= pd.read_sql_query(query6,sqldb)
op
# Out:
#         product_id
# 0  FUR-BO-10001798
# 1  FUR-CH-10000454
# 2  FUR-FU-10001487
# 3  FUR-TA-10000577
# 4  FUR-TA-10001539

# %%
query7="select * from dept"

# %%
op= pd.read_sql_query(query7,sqldb)
op
# Out:
#    deptno       dname  location
# 0      10  Accounting  New York
# 1      20    Research    Dallas
# 2      30       Sales   Chicago
# 3      40  Operations    Boston

# %%
query8="select location, deptno from dept where dname='Research'" # , select specific

# %%
op= pd.read_sql_query(query8,sqldb)
op
# Out:
#   location  deptno
# 0   Dallas      20

# %%
query9 ="select * from salgrade"

# %%
op= pd.read_sql_query(query9,sqldb)
op
# Out:
#    grade   losal    hisal
# 0      1   700.0   1200.0
# 1      2  1201.0   1400.0
# 2      3  1401.0   2000.0
# 3      4  2001.0   3000.0
# 4      5  3001.0  99999.0

# %%
query10="select losal,hisal  from salgrade where grade>3" # , select specific

# %%
op= pd.read_sql_query(query10,sqldb)
op
# Out:
#     losal    hisal
# 0  2001.0   3000.0
# 1  3001.0  99999.0

# %%
query11="select * from customers"

# %%
op= pd.read_sql_query(query11,sqldb)
op
# Out:
#   customer_id       customer_name             city           state  \
# 0    AA-10480        Andrew Allen          Concord  North Carolina
# 1    AG-10270     Alejandro Grove      West Jordan            Utah
# 2    BH-11710     Brosina Hoffman      Los Angeles      California
# 3    CG-12520         Claire Gute        Henderson        Kentucky
# 4    DV-13045     Darrin Van Huff      Los Angeles      California
# 5    HP-14815       Harold Pawlan       Fort Worth           Texas
# 6    IM-15070        Irene Maddox          Seattle      Washington
# 7    PK-19075           Pete Kriz          Madison       Wisconsin
# 8    SO-20335      Sean O'Donnell  Fort Lauderdale         Florida
# 9    ZD-21925  Zuschuss Donatelli    San Francisco      California
#
#    postal_code
# 0        28027
# 1        84084
# 2        90032
# 3        42420
# 4        90036
# 5        76106
# 6        98103
# 7        53711
# 8        33311
# 9        94109

# %%
query10="select city,state  from customers where postal_code<50000" # , select specific

# %%
op= pd.read_sql_query(query10,sqldb)
op
# Out:
#               city           state
# 0          Concord  North Carolina
# 1        Henderson        Kentucky
# 2  Fort Lauderdale         Florida

# %%
# distinct

# %%
query='select distinct state from customers'
op=pd.read_sql_query(query,sqldb)
op
# Out:
#             state
# 0  North Carolina
# 1            Utah
# 2      California
# 3        Kentucky
# 4           Texas
# 5      Washington
# 6       Wisconsin
# 7         Florida

# %%
query='select count(distinct job) from emp'
op=pd.read_sql_query(query,sqldb)
op
# Out:
#    count(distinct job)
# 0                    5

# %%
query='select distinct job from emp'
op=pd.read_sql_query(query,sqldb)
op
# Out:
#          job
# 0      CLERK
# 1   SALESMAN
# 2    MANAGER
# 3    ANALYST
# 4  PRESIDENT

# %%
query15='select * from emp where job="SALESMAN" and sal>1300'

# %%
op=pd.read_sql_query(query15,sqldb)
op
# Out:
#    empno   ename       job   mgr    hiredate     sal   comm  deptno
# 0   7499   ALLEN  SALESMAN  7698  1998-08-15  1600.0  300.0      30
# 1   7844  TURNER  SALESMAN  7698  1995-06-04  1500.0    0.0      30

# %%
query16='select empno,ename from emp where job="SALESMAN" and sal>1300'

# %%
op=pd.read_sql_query(query16,sqldb)
op
# Out:
#    empno   ename
# 0   7499   ALLEN
# 1   7844  TURNER

# %%
query16="select * from customers"

# %%
op=pd.read_sql_query(query16,sqldb)
op
# Out:
#   customer_id       customer_name             city           state  \
# 0    AA-10480        Andrew Allen          Concord  North Carolina
# 1    AG-10270     Alejandro Grove      West Jordan            Utah
# 2    BH-11710     Brosina Hoffman      Los Angeles      California
# 3    CG-12520         Claire Gute        Henderson        Kentucky
# 4    DV-13045     Darrin Van Huff      Los Angeles      California
# 5    HP-14815       Harold Pawlan       Fort Worth           Texas
# 6    IM-15070        Irene Maddox          Seattle      Washington
# 7    PK-19075           Pete Kriz          Madison       Wisconsin
# 8    SO-20335      Sean O'Donnell  Fort Lauderdale         Florida
# 9    ZD-21925  Zuschuss Donatelli    San Francisco      California
#
#    postal_code
# 0        28027
# 1        84084
# 2        90032
# 3        42420
# 4        90036
# 5        76106
# 6        98103
# 7        53711
# 8        33311
# 9        94109

# %%
query17='select customer_name from customers where city="Seattle" or state="California"'

# %%
op=pd.read_sql_query(query17,sqldb)
print(op.shape)
op
# Out:
# (4, 1)
#         customer_name
# 0     Brosina Hoffman
# 1     Darrin Van Huff
# 2        Irene Maddox
# 3  Zuschuss Donatelli

# %%
query18='select  count(sub_category),category from products group by category'

# %%
op=pd.read_sql_query(query18,sqldb)
print(op.shape)
op
# Out:
# (3, 2)
#    count(sub_category)         category
# 0                    5        Furniture
# 1                    7  Office Supplies
# 2                    2       Technology

# %%
# in  emp
# group by job
# extract max salary

# %%
query18='select max(sal),job  from emp group by job'

# %%
op=pd.read_sql_query(query18,sqldb)
print(op.shape)
op
# Out:
# (5, 2)
#    max(sal)        job
# 0    3000.0    ANALYST
# 1    1300.0      CLERK
# 2    2975.0    MANAGER
# 3    5000.0  PRESIDENT
# 4    1600.0   SALESMAN

# %%
query4="select * from products"
op=pd.read_sql_query(query4,sqldb)
op
# Out:
#          product_id         category sub_category  \
# 0   FUR-BO-10001798        Furniture    Bookcases
# 1   FUR-CH-10000454        Furniture       Chairs
# 2   FUR-FU-10001487        Furniture  Furnishings
# 3   FUR-TA-10000577        Furniture       Tables
# 4   FUR-TA-10001539        Furniture       Tables
# 5   OFF-AP-10002892  Office Supplies   Appliances
# 6   OFF-AR-10002833  Office Supplies          Art
# 7   OFF-BI-10003656  Office Supplies      Binders
# 8   OFF-BI-10003910  Office Supplies      Binders
# 9   OFF-LA-10000240  Office Supplies       Labels
# 10  OFF-PA-10002365  Office Supplies        Paper
# 11  OFF-ST-10000760  Office Supplies      Storage
# 12  TEC-PH-10002033       Technology       Phones
# 13  TEC-PH-10002275       Technology       Phones
#
#                                          product_name
# 0                   Bush Somerset Collection Bookcase
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...
# ...

# %%
query18='select  count(distinct sub_category),category from products group by category'
op=pd.read_sql_query(query18,sqldb)
op
# Out:
#    count(distinct sub_category)         category
# 0                             4        Furniture
# 1                             6  Office Supplies
# 2                             1       Technology

# %%
# order by command

query18='select *   from emp order by sal desc'
op=pd.read_sql_query(query18,sqldb)
op
# Out:
#     empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN  1990-06-09  5000.0     0.0      10
# 1    7788   SCOTT    ANALYST  7566.0  1996-03-05  3000.0     NaN      20
# 2    7902    FORD    ANALYST  7566.0  1997-12-05  3000.0     NaN      20
# 3    7566   JONES    MANAGER  7839.0  1995-10-31  2975.0     NaN      20
# 4    7698   BLAKE    MANAGER  7839.0  1992-06-11  2850.0     NaN      30
# 5    7782   CLARK    MANAGER  7839.0  1993-05-14  2450.0     NaN      10
# 6    7499   ALLEN   SALESMAN  7698.0  1998-08-15  1600.0   300.0      30
# 7    7844  TURNER   SALESMAN  7698.0  1995-06-04  1500.0     0.0      30
# 8    7934  MILLER      CLERK  7782.0  2000-01-21  1300.0     NaN      10
# 9    7521    WARD   SALESMAN  7698.0  1996-03-26  1250.0   500.0      30
# 10   7654  MARTIN   SALESMAN  7698.0  1998-12-05  1250.0  1400.0      30
# 11   7876   ADAMS      CLERK  7788.0  1999-06-04  1100.0     NaN      20
# ...

# %%
query18='select *   from emp order by sal ,job'
op=pd.read_sql_query(query18,sqldb)
op
# Out:
#     empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0    7369   SMITH      CLERK  7902.0  1993-06-13   800.0     0.0      20
# 1    7900   JAMES      CLERK  7698.0  2000-06-23   950.0     NaN      30
# 2    7876   ADAMS      CLERK  7788.0  1999-06-04  1100.0     NaN      20
# 3    7521    WARD   SALESMAN  7698.0  1996-03-26  1250.0   500.0      30
# 4    7654  MARTIN   SALESMAN  7698.0  1998-12-05  1250.0  1400.0      30
# 5    7934  MILLER      CLERK  7782.0  2000-01-21  1300.0     NaN      10
# 6    7844  TURNER   SALESMAN  7698.0  1995-06-04  1500.0     0.0      30
# 7    7499   ALLEN   SALESMAN  7698.0  1998-08-15  1600.0   300.0      30
# 8    7782   CLARK    MANAGER  7839.0  1993-05-14  2450.0     NaN      10
# 9    7698   BLAKE    MANAGER  7839.0  1992-06-11  2850.0     NaN      30
# 10   7566   JONES    MANAGER  7839.0  1995-10-31  2975.0     NaN      20
# 11   7788   SCOTT    ANALYST  7566.0  1996-03-05  3000.0     NaN      20
# ...

# %%
# nan value

# %%
query18='select *   from emp  where comm is null'
op=pd.read_sql_query(query18,sqldb)
op
# Out:
#    empno   ename      job   mgr    hiredate     sal  comm  deptno
# 0   7566   JONES  MANAGER  7839  1995-10-31  2975.0  None      20
# 1   7698   BLAKE  MANAGER  7839  1992-06-11  2850.0  None      30
# 2   7782   CLARK  MANAGER  7839  1993-05-14  2450.0  None      10
# 3   7788   SCOTT  ANALYST  7566  1996-03-05  3000.0  None      20
# 4   7876   ADAMS    CLERK  7788  1999-06-04  1100.0  None      20
# 5   7900   JAMES    CLERK  7698  2000-06-23   950.0  None      30
# 6   7902    FORD  ANALYST  7566  1997-12-05  3000.0  None      20
# 7   7934  MILLER    CLERK  7782  2000-01-21  1300.0  None      10

# %%
query19='select *   from emp  where comm is not null'
op=pd.read_sql_query(query19,sqldb)
op
# Out:
#    empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0   7369   SMITH      CLERK  7902.0  1993-06-13   800.0     0.0      20
# 1   7499   ALLEN   SALESMAN  7698.0  1998-08-15  1600.0   300.0      30
# 2   7521    WARD   SALESMAN  7698.0  1996-03-26  1250.0   500.0      30
# 3   7654  MARTIN   SALESMAN  7698.0  1998-12-05  1250.0  1400.0      30
# 4   7839    KING  PRESIDENT     NaN  1990-06-09  5000.0     0.0      10
# 5   7844  TURNER   SALESMAN  7698.0  1995-06-04  1500.0     0.0      30

# %%
# this is aggregatiomn multiple combination of operation

query19='select  max(sal)   from emp  where  deptno >20'
op=pd.read_sql_query(query19,sqldb)
op
# Out:
#    max(sal)
# 0    2850.0

# %%
query ='select * from emp where ename like "a%"'
op=pd.read_sql_query(query,sqldb)
op
# Out:
#    empno  ename       job   mgr    hiredate     sal   comm  deptno
# 0   7499  ALLEN  SALESMAN  7698  1998-08-15  1600.0  300.0      30
# 1   7876  ADAMS     CLERK  7788  1999-06-04  1100.0    NaN      20

# %%
query ='select * from emp where ename like "%r"'
op=pd.read_sql_query(query,sqldb)
op
# Out:
#    empno   ename       job   mgr    hiredate     sal  comm  deptno
# 0   7844  TURNER  SALESMAN  7698  1995-06-04  1500.0   0.0      30
# 1   7934  MILLER     CLERK  7782  2000-01-21  1300.0   NaN      10

# %%
query ='select * from emp where ename like "%le%"'
op=pd.read_sql_query(query,sqldb)
op
# Out:
#    empno   ename       job   mgr    hiredate     sal   comm  deptno
# 0   7499   ALLEN  SALESMAN  7698  1998-08-15  1600.0  300.0      30
# 1   7934  MILLER     CLERK  7782  2000-01-21  1300.0    NaN      10

# %%
query ='select * from emp where ename like "%_l%"'
op=pd.read_sql_query(query,sqldb)
op
# Out:
#    empno   ename       job   mgr    hiredate     sal   comm  deptno
# 0   7499   ALLEN  SALESMAN  7698  1998-08-15  1600.0  300.0      30
# 1   7698   BLAKE   MANAGER  7839  1992-06-11  2850.0    NaN      30
# 2   7782   CLARK   MANAGER  7839  1993-05-14  2450.0    NaN      10
# 3   7934  MILLER     CLERK  7782  2000-01-21  1300.0    NaN      10

# %%
query ='select * from emp where ename like "_a%"'
op=pd.read_sql_query(query,sqldb)
op
# Out:
#    empno   ename       job   mgr    hiredate     sal    comm  deptno
# 0   7521    WARD  SALESMAN  7698  1996-03-26  1250.0   500.0      30
# 1   7654  MARTIN  SALESMAN  7698  1998-12-05  1250.0  1400.0      30
# 2   7900   JAMES     CLERK  7698  2000-06-23   950.0     NaN      30
